# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Load Data

# %%
#loading log data of the gru
own_train = pd.read_csv('results/cnn_train_own_embedding_trainable_training_csv.log)
own_untrain = pd.read_csv('results/cnn_train_own_embedding_untrainable_training_csv.log
glove_train = pd.read_csv('gru2_2/training_csv.log')
glove_untrain = pd.read_csv('gru1_2/training_csv.log')
no_pre = pd.read_csv('gru2_1/training_csv.log')
# Out:
#    epoch       loss  mean_squared_error   val_loss  val_mean_squared_error
# 0      0  15.140515           15.140515  13.028655               13.028655
# 1      1  14.142669           14.142669  13.037051               13.037051
# 2      2  14.072731           14.072731  12.943968               12.943968
# 3      3  13.930772           13.930772  12.644093               12.644093
# 4      4  13.690778           13.690778  12.423619               12.423619

# %%
#loading log data of the lstm network
lstm1_2 = pd.read_csv('lstm1_2/training_csv.log')
lstm2_1 = pd.read_csv('lstm2_1/training_csv.log')
lstm2_2 = pd.read_csv('lstm2_2/training_csv.log')

# %%
fig, axes = plt.subplots(3, 1, figsize=(12, 12))

axes[0].plot(lstm1_2['epoch'],lstm1_2['val_mean_squared_error'], 'b',label = 'lstm_validation')
axes[0].plot(lstm1_2['epoch'],lstm1_2['mean_squared_error'], 'g',label = 'lstm_train')

axes[0].plot(gru1_2['epoch'],gru1_2['val_mean_squared_error'], 'y',label = 'gru_validation')
axes[0].plot(gru1_2['epoch'],gru1_2['mean_squared_error'], 'r',label = 'gru_train')

axes[0].set_title("Without Scaler")
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Mean Squared Error')
axes[0].legend()

axes[1].plot(lstm2_1['epoch'],lstm2_1['val_mean_squared_error'], 'b',label = 'lstm_validation')
axes[1].plot(lstm2_1['epoch'],lstm2_1['mean_squared_error'], 'g',label = 'lstm_train')

axes[1].plot(gru2_1['epoch'],gru2_1['val_mean_squared_error'], 'y',label = 'gru_validation')
axes[1].plot(gru2_1['epoch'],gru2_1['mean_squared_error'], 'r',label = 'gru_train')

axes[1].set_title("Min Max Scaler")
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Mean Squared Error')
axes[1].legend()

axes[2].plot(lstm2_2['epoch'],lstm2_2['val_mean_squared_error'], 'b',label = 'lstm_validation')
axes[2].plot(lstm2_2['epoch'],lstm2_2['mean_squared_error'], 'g',label = 'lstm_train')

axes[2].plot(gru2_2['epoch'],gru2_2['val_mean_squared_error'], 'y',label = 'gru_validation')
axes[2].plot(gru2_2['epoch'],gru2_2['mean_squared_error'], 'r',label = 'gru_train')

axes[2].set_title("Standard Scaler")
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Mean Squared Error')
axes[2].legend()
plt.tight_layout()

# %%
gru3_1 = pd.read_csv('gru3_1/training_csv.log')

# %%
# Create Figure (empty canvas)
fig = plt.figure()

# Add set of axes to figure
axes = fig.add_axes([0, 0, 1, 1]) # left, bottom, width, height (range 0 to 1)


axes.plot(gru3_1['epoch'],gru3_1['val_mean_squared_error'], 'b',label = 'improved _gru_validation_MSE')
axes.plot(gru3_1['epoch'],gru3_1['mean_squared_error'], 'g',label = 'improved_gru_MSE')


axes.plot(gru2_2['epoch'],gru2_2['val_mean_squared_error'], 'y',label = 'gru_validation_MSE')
axes.plot(gru2_2['epoch'],gru2_2['mean_squared_error'], 'r',label = 'gru_MSE')

axes.set_title("Improved GRU with Standard Scaler")
axes.set_xlabel('Epochs')
axes.set_ylabel('Mean Squared Error')
axes.legend()
plt.tight_layout()
# Out:
# /home/buchholz/.local/lib/python3.6/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
gru4_2 = pd.read_csv('gru4_2/training_csv.log')

# %%
# Create Figure (empty canvas)
fig = plt.figure()

# Add set of axes to figure
axes = fig.add_axes([0, 0, 1, 1]) # left, bottom, width, height (range 0 to 1)


axes.plot(gru4_2['epoch'],gru4_2['val_mean_squared_error'], 'b',label = 'validation_MSE')
axes.plot(gru4_2['epoch'],gru4_2['mean_squared_error'], 'g',label = 'training_MSE')


axes.set_title("Mix CNN and GRU")
axes.set_xlabel('Epochs')
axes.set_ylabel('Mean Squared Error')
axes.legend()
plt.tight_layout()
